# %%
from __future__ import division
import os
import cv2
import numpy as np
import sys
import pickle
from optparse import OptionParser
import time
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from keras_frcnn import config
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from keras_frcnn import data_generators
from keras_frcnn import losses as losses
import keras_frcnn.roi_helpers as roi_helpers
from keras_frcnn.simple_parser import get_data
from keras.utils import generic_utils

def format_img_size(img, C):
    """ formats the image size based on config """
    img_min_side = float(C.im_size)
    (height,width,_) = img.shape
        
    if width <= height:
        ratio = img_min_side/width
        new_height = int(ratio * height)
        new_width = int(img_min_side)
    else:
        ratio = img_min_side/height
        new_width = int(ratio * width)
        new_height = int(img_min_side)
    img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
    return img, ratio    

def format_img_channels(img, C):
    """ formats the image channels based on config """
    img = img[:, :, (2, 1, 0)]
    img = img.astype(np.float32)
    img[:, :, 0] -= C.img_channel_mean[0]
    img[:, :, 1] -= C.img_channel_mean[1]
    img[:, :, 2] -= C.img_channel_mean[2]
    img /= C.img_scaling_factor
    img = np.transpose(img, (2, 0, 1))
    img = np.expand_dims(img, axis=0)
    return img

def format_img(img, C):
    """ formats an image for model prediction based on config """
    img, ratio = format_img_size(img, C)
    img = format_img_channels(img, C)
    return img, ratio

# Method to transform the coordinates of the bounding box to its original size
def get_real_coordinates(ratio, x1, y1, x2, y2):

    real_x1 = int(round(x1 // ratio))
    real_y1 = int(round(y1 // ratio))
    real_x2 = int(round(x2 // ratio))
    real_y2 = int(round(y2 // ratio))

    return (real_x1, real_y1, real_x2 ,real_y2)

sys.setrecursionlimit(40000)
# Out:
# Using TensorFlow backend.

# %%
test_path = '/home/dkube/work/workspace/split/test/annot.txt'
num_rois = 32
parser = "simple"
network = 'resnet50'
horizontal_flips = False
vertical_flips = False
rot_90 = False
num_epochs = 5
config_filename = "config.pickle"

# %%
# data_path = '/opt/dkube/input/'/

model_path ='/home/dkube/work/workspace/model/'

config_output_filename = model_path +  config_filename

with open(config_output_filename, 'rb') as f_in:
    C = pickle.load(f_in)

if C.network == 'resnet50':
    import keras_frcnn.resnet as nn
elif C.network == 'vgg':
    import keras_frcnn.vgg as nn

# turn off any data augmentation at test time
C.use_horizontal_flips = False
C.use_vertical_flips = False
C.rot_90 = False

class_mapping = C.class_mapping
    
    
all_imgs, classes_count, class_mapping = get_data( test_path)

if 'bg' not in classes_count:
    classes_count['bg'] = 0
    class_mapping['bg'] = len(class_mapping)
    
test_imgs = [s for s in all_imgs if s['imageset'] == 'trainval' or s['imageset'] == 'test']

print('Num test samples {}'.format(len(test_imgs)))

data_gen_test = data_generators.get_anchor_gt(test_imgs, classes_count, C, nn.get_img_output_length, mode='val')

C.num_rois = int( num_rois)

if C.network == 'resnet50':
    num_features = 1024
elif C.network == 'vgg':
    num_features = 512


input_shape_img = (600,600, 3)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(None, 4))
# feature_map_input = Input(shape=input_shape_features)

shared_layers = nn.nn_base(img_input, trainable=True)

# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn = nn.rpn(shared_layers, num_anchors)

classifier = nn.classifier(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count), trainable=True)

model_rpn = Model(img_input, rpn[:2])
model_classifier = Model([img_input, roi_input], classifier)

C.model_path = model_path + 'weights.h5'


print('Loading weights from {}'.format(C.model_path))
model_rpn.load_weights(C.model_path, by_name=True)
model_classifier.load_weights(C.model_path, by_name=True)

optimizer = Adam(lr=1e-5)
optimizer_classifier = Adam(lr=1e-5)
model_rpn.compile(optimizer=optimizer, loss=[losses.rpn_loss_cls(num_anchors), losses.rpn_loss_regr(num_anchors)])
model_classifier.compile(optimizer=optimizer_classifier, loss=[losses.class_loss_cls, losses.class_loss_regr(len(classes_count)-1)], metrics={'dense_class_{}'.format(len(classes_count)): 'accuracy'})

################# Evaluating #################################
start_time = time.time()
losses = np.zeros((len(test_imgs), 5))
rpn_accuracy_rpn_monitor = []
rpn_accuracy_for_epoch = []
iter_num = 0
metric_names = ['loss_rpn_cls','loss_rpn_regr', 'loss_class_cls',
                'loss_class_regr', 'class_acc', 'mean_overlapping_bboxes']
progbar = generic_utils.Progbar(len(test_imgs))
print('Evaluating {} samples'.format(len(test_imgs)))
# Out:
# Parsing annotation files
# WARNING: Logging before flag parsing goes to stderr.
# W0218 10:49:54.715251 139647266563904 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Num test samples 299
# <class 'tensorflow.python.framework.ops.Tensor'>
# W0218 10:49:58.998305 139647266563904 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0218 10:49:59.033451 139647266563904 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0218 10:49:59.168641 139647266563904 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/converters/directives.py:117: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
# Loading weights from /home/dkube/work/workspace/model/weights.h5
# Evaluating 299 samples

# %%
while True:
    X, Y, img_data = next(data_gen_test)
    loss_rpn = model_rpn.evaluate(X, Y)
    P_rpn = model_rpn.predict_on_batch(X)

    R = roi_helpers.rpn_to_roi(P_rpn[0], P_rpn[1], C, use_regr=True, overlap_thresh=0.7, max_boxes=300)
    # note: calc_iou converts from (x1,y1,x2,y2) to (x,y,w,h) format
    X2, Y1, Y2, IouS = roi_helpers.calc_iou(R, img_data, C, class_mapping)

    if X2 is None:
        rpn_accuracy_rpn_monitor.append(0)
        rpn_accuracy_for_epoch.append(0)
        continue

    neg_samples = np.where(Y1[0, :, -1] == 1)
    pos_samples = np.where(Y1[0, :, -1] == 0)

    if len(neg_samples) > 0:
        neg_samples = neg_samples[0]
    else:
        neg_samples = []

    if len(pos_samples) > 0:
        pos_samples = pos_samples[0]
    else:
        pos_samples = []
    
    rpn_accuracy_rpn_monitor.append(len(pos_samples))
    rpn_accuracy_for_epoch.append((len(pos_samples)))

    if C.num_rois > 1:
        if len(pos_samples) < C.num_rois//2:
            selected_pos_samples = pos_samples.tolist()
        else:
            selected_pos_samples = np.random.choice(pos_samples, C.num_rois//2, replace=False).tolist()
        try:
            selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=False).tolist()
        except:
            selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=True).tolist()

        sel_samples = selected_pos_samples + selected_neg_samples
    else:
        # in the extreme case where num_rois = 1, we pick a random pos or neg sample
        selected_pos_samples = pos_samples.tolist()
        selected_neg_samples = neg_samples.tolist()
        if np.random.randint(0, 2):
            sel_samples = random.choice(neg_samples)
        else:
            sel_samples = random.choice(pos_samples)

    loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])

    losses[iter_num, 0] = loss_rpn[1]
    losses[iter_num, 1] = loss_rpn[2]

    losses[iter_num, 2] = loss_class[1]
    losses[iter_num, 3] = loss_class[2]
    losses[iter_num, 4] = loss_class[3]

    progbar.update(iter_num+1, [('rpn_cls', losses[iter_num, 0]), ('rpn_regr', losses[iter_num, 1]),
                                ('detector_cls', losses[iter_num, 2]), ('detector_regr', losses[iter_num, 3])])

    iter_num += 1
    
    if iter_num == len(test_imgs):
        loss_rpn_cls = np.mean(losses[:, 0])
        loss_rpn_regr = np.mean(losses[:, 1])
        loss_class_cls = np.mean(losses[:, 2])
        loss_class_regr = np.mean(losses[:, 3])
        class_acc = np.mean(losses[:, 4])
        mean_overlapping_bboxes = float(sum(rpn_accuracy_for_epoch)) / len(rpn_accuracy_for_epoch)
        
        rpn_accuracy_for_epoch = []
        
        if C.verbose:
            print('Mean number of bounding boxes from RPN overlapping ground truth boxes: {}'.format(mean_overlapping_bboxes))
            print('Classifier accuracy for bounding boxes from RPN: {}'.format(class_acc))
            print('Loss RPN classifier: {}'.format(loss_rpn_cls))
            print('Loss RPN regression: {}'.format(loss_rpn_regr))
            print('Loss Detector classifier: {}'.format(loss_class_cls))
            print('Loss Detector regression: {}'.format(loss_class_regr))
            print('Elapsed time: {}'.format(time.time() - start_time))
        break
# Out:
# 1/1 [==============================] - 2s 2s/sample - loss: 2.7752 - rpn_out_class_loss: 1.9270 - rpn_out_regress_loss: 0.8482
# W0218 10:50:18.281562 139647266563904 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 1/1 [==============================] - 1s 978ms/sample - loss: 0.9678 - rpn_out_class_loss: 0.8305 - rpn_out_regress_loss: 0.1374gr: 0.4997
# 1/1 [==============================] - 1s 897ms/sample - loss: 2.9177 - rpn_out_class_loss: 2.8766 - rpn_out_regress_loss: 0.0411gr: 0.4349
# 1/1 [==============================] - 1s 1s/sample - loss: 2.9674 - rpn_out_class_loss: 2.9301 - rpn_out_regress_loss: 0.0374_regr: 0.3999
# 1/1 [==============================] - 1s 814ms/sample - loss: 3.3802 - rpn_out_class_loss: 3.2186 - rpn_out_regress_loss: 0.1616gr: 0.3867
# 1/1 [==============================] - 1s 851ms/sample - loss: 3.2623 - rpn_out_class_loss: 3.2054 - rpn_out_regress_loss: 0.0569gr: 0.3754
# 1/1 [==============================] - 1s 709ms/sample - loss: 3.6639 - rpn_out_class_loss: 3.2051 - rpn_out_regress_loss: 0.4589: 0.3835
# 1/1 [==============================] - 1s 1s/sample - loss: 2.3430 - rpn_out_class_loss: 2.1913 - rpn_out_regress_loss: 0.1517egr: 0.3905
# 1/1 [==============================] - 1s 1s/sample - loss: 1.8748 - rpn_out_class_loss: 1.6405 - rpn_out_regress_loss: 0.2343egr: 0.4015
# 1/1 [==============================] - 1s 1s/sample - loss: 3.6931 - rpn_out_class_loss: 3.4707 - rpn_out_regress_loss: 0.2224egr: 0.4075
# 1/1 [==============================] - 1s 1s/sample - loss: 0.9771 - rpn_out_class_loss: 0.6746 - rpn_out_regress_loss: 0.3025egr: 0.4014
# 1/1 [==============================] - 1s 819ms/sample - loss: 2.1194 - rpn_out_class_loss: 1.7117 - rpn_out_regress_loss: 0.4077: 0.4053
# 1/1 [==============================] - 1s 813ms/sample - loss: 2.1288 - rpn_out_class_loss: 1.7399 - rpn_out_regress_loss: 0.3888: 0.4048
# 1/1 [==============================] - 1s 663ms/sample - loss: 2.8761 - rpn_out_class_loss: 2.7678 - rpn_out_regress_loss: 0.1083: 0.4072
# 1/1 [==============================] - 1s 1s/sample - loss: 3.3306 - rpn_out_class_loss: 3.1814 - rpn_out_regress_loss: 0.1492egr: 0.4078
# 1/1 [==============================] - 1s 1s/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 779ms/sample - loss: 0.1910 - rpn_out_class_loss: 0.0597 - rpn_out_regress_loss: 0.1313
# 1/1 [==============================] - 1s 1s/sample - loss: 3.4906 - rpn_out_class_loss: 3.2965 - rpn_out_regress_loss: 0.1942egr: 0.4120
# 1/1 [==============================] - 1s 1s/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 1s/sample - loss: 2.3339 - rpn_out_class_loss: 2.0523 - rpn_out_regress_loss: 0.2816
# 1/1 [==============================] - 1s 745ms/sample - loss: 2.9849 - rpn_out_class_loss: 2.6289 - rpn_out_regress_loss: 0.3559: 0.4145
# 1/1 [==============================] - 1s 1s/sample - loss: 1.9192 - rpn_out_class_loss: 1.4280 - rpn_out_regress_loss: 0.4912egr: 0.4152
# 1/1 [==============================] - 1s 1s/sample - loss: 4.7447 - rpn_out_class_loss: 4.6467 - rpn_out_regress_loss: 0.0979egr: 0.4195
# 1/1 [==============================] - 1s 881ms/sample - loss: 3.9059 - rpn_out_class_loss: 3.6218 - rpn_out_regress_loss: 0.2841: 0.4212
# 1/1 [==============================] - 1s 930ms/sample - loss: 2.5824 - rpn_out_class_loss: 2.4061 - rpn_out_regress_loss: 0.1763: 0.4221
# 1/1 [==============================] - 1s 782ms/sample - loss: 2.2302 - rpn_out_class_loss: 1.8748 - rpn_out_regress_loss: 0.3554: 0.4183
# 1/1 [==============================] - 1s 956ms/sample - loss: 2.5898 - rpn_out_class_loss: 2.5045 - rpn_out_regress_loss: 0.0854: 0.4161
# 1/1 [==============================] - 1s 785ms/sample - loss: 3.8918 - rpn_out_class_loss: 3.2003 - rpn_out_regress_loss: 0.6915: 0.4125
# 1/1 [==============================] - 1s 1s/sample - loss: 1.5386 - rpn_out_class_loss: 1.4503 - rpn_out_regress_loss: 0.0883egr: 0.4113
# 1/1 [==============================] - 1s 731ms/sample - loss: 3.0258 - rpn_out_class_loss: 2.7775 - rpn_out_regress_loss: 0.2483: 0.4148
# 1/1 [==============================] - 1s 715ms/sample - loss: 6.1392 - rpn_out_class_loss: 5.5684 - rpn_out_regress_loss: 0.5708: 0.4143
# 1/1 [==============================] - 1s 964ms/sample - loss: 2.2711 - rpn_out_class_loss: 2.0409 - rpn_out_regress_loss: 0.2302: 0.4000
# 1/1 [==============================] - 1s 817ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 787ms/sample - loss: 3.4881 - rpn_out_class_loss: 3.2664 - rpn_out_regress_loss: 0.2217
# 1/1 [==============================] - 1s 1s/sample - loss: 3.7941 - rpn_out_class_loss: 3.5014 - rpn_out_regress_loss: 0.2927egr: 0.4102
# 1/1 [==============================] - 2s 2s/sample - loss: 2.6620 - rpn_out_class_loss: 2.5373 - rpn_out_regress_loss: 0.1247egr: 0.4096
# 1/1 [==============================] - 1s 803ms/sample - loss: 1.9060 - rpn_out_class_loss: 1.7046 - rpn_out_regress_loss: 0.2014: 0.4104
# 1/1 [==============================] - 1s 1000ms/sample - loss: 4.6537 - rpn_out_class_loss: 4.5092 - rpn_out_regress_loss: 0.1446 0.4062
# 1/1 [==============================] - 1s 944ms/sample - loss: 3.0773 - rpn_out_class_loss: 2.9955 - rpn_out_regress_loss: 0.0818: 0.4061
# 1/1 [==============================] - 1s 949ms/sample - loss: 2.7459 - rpn_out_class_loss: 2.5035 - rpn_out_regress_loss: 0.2424: 0.4054
# 1/1 [==============================] - 1s 1s/sample - loss: 3.9730 - rpn_out_class_loss: 3.6901 - rpn_out_regress_loss: 0.2830egr: 0.4019
# 1/1 [==============================] - 1s 751ms/sample - loss: 3.1194 - rpn_out_class_loss: 2.9221 - rpn_out_regress_loss: 0.1973: 0.3992
# 1/1 [==============================] - 1s 997ms/sample - loss: 3.5263 - rpn_out_class_loss: 3.0337 - rpn_out_regress_loss: 0.4926: 0.3967
# 1/1 [==============================] - 1s 892ms/sample - loss: 0.4194 - rpn_out_class_loss: 0.3124 - rpn_out_regress_loss: 0.1070: 0.3957
# 1/1 [==============================] - 1s 990ms/sample - loss: 2.8212 - rpn_out_class_loss: 2.5479 - rpn_out_regress_loss: 0.2733: 0.3957
# 1/1 [==============================] - 2s 2s/sample - loss: 0.6870 - rpn_out_class_loss: 0.4987 - rpn_out_regress_loss: 0.1883egr: 0.3948
# 1/1 [==============================] - 1s 862ms/sample - loss: 2.5103 - rpn_out_class_loss: 2.4533 - rpn_out_regress_loss: 0.0570: 0.3965
# 1/1 [==============================] - 1s 932ms/sample - loss: 3.8971 - rpn_out_class_loss: 3.4046 - rpn_out_regress_loss: 0.4925: 0.3953
# 1/1 [==============================] - 1s 1s/sample - loss: 2.1479 - rpn_out_class_loss: 1.4716 - rpn_out_regress_loss: 0.6762egr: 0.3968
# 1/1 [==============================] - 1s 1s/sample - loss: 1.9006 - rpn_out_class_loss: 1.6855 - rpn_out_regress_loss: 0.2151egr: 0.3955
# 1/1 [==============================] - 1s 1s/sample - loss: 3.5531 - rpn_out_class_loss: 3.2237 - rpn_out_regress_loss: 0.3293egr: 0.3948
# 1/1 [==============================] - 1s 629ms/sample - loss: 3.7679 - rpn_out_class_loss: 3.2745 - rpn_out_regress_loss: 0.4934: 0.3938
# 1/1 [==============================] - 1s 972ms/sample - loss: 3.1841 - rpn_out_class_loss: 3.1010 - rpn_out_regress_loss: 0.0831: 0.3947
# 1/1 [==============================] - 1s 829ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 847ms/sample - loss: 3.0578 - rpn_out_class_loss: 2.8563 - rpn_out_regress_loss: 0.2015
# 1/1 [==============================] - 1s 809ms/sample - loss: 4.8820 - rpn_out_class_loss: 4.5587 - rpn_out_regress_loss: 0.3232: 0.3937
# 1/1 [==============================] - 1s 634ms/sample - loss: 2.9106 - rpn_out_class_loss: 2.4696 - rpn_out_regress_loss: 0.4409: 0.3933
# 1/1 [==============================] - 1s 658ms/sample - loss: 3.5737 - rpn_out_class_loss: 3.2858 - rpn_out_regress_loss: 0.2879: 0.3922
# 1/1 [==============================] - 1s 926ms/sample - loss: 3.1753 - rpn_out_class_loss: 2.9221 - rpn_out_regress_loss: 0.2533: 0.3901
# 1/1 [==============================] - 1s 662ms/sample - loss: 2.2597 - rpn_out_class_loss: 2.0766 - rpn_out_regress_loss: 0.1831: 0.3894
# 1/1 [==============================] - 1s 1s/sample - loss: 3.0749 - rpn_out_class_loss: 1.7515 - rpn_out_regress_loss: 1.3233egr: 0.3892
# 1/1 [==============================] - 1s 1000ms/sample - loss: 3.2501 - rpn_out_class_loss: 3.0406 - rpn_out_regress_loss: 0.2095 0.3823
# 1/1 [==============================] - 1s 900ms/sample - loss: 2.3920 - rpn_out_class_loss: 2.2523 - rpn_out_regress_loss: 0.1396: 0.3832
# 1/1 [==============================] - 1s 724ms/sample - loss: 2.5962 - rpn_out_class_loss: 2.3541 - rpn_out_regress_loss: 0.2422: 0.3841
# 1/1 [==============================] - 1s 955ms/sample - loss: 1.8262 - rpn_out_class_loss: 1.6330 - rpn_out_regress_loss: 0.1932: 0.3849
# 1/1 [==============================] - 1s 1s/sample - loss: 3.4017 - rpn_out_class_loss: 3.2402 - rpn_out_regress_loss: 0.1615egr: 0.3861
# 1/1 [==============================] - 1s 1s/sample - loss: 2.6733 - rpn_out_class_loss: 0.1076 - rpn_out_regress_loss: 2.5657egr: 0.3860
# 1/1 [==============================] - 1s 1s/sample - loss: 4.1661 - rpn_out_class_loss: 4.0032 - rpn_out_regress_loss: 0.1629
# 1/1 [==============================] - 1s 913ms/sample - loss: 2.7346 - rpn_out_class_loss: 2.5402 - rpn_out_regress_loss: 0.1944: 0.3891
# 1/1 [==============================] - 1s 1s/sample - loss: 2.8780 - rpn_out_class_loss: 2.6405 - rpn_out_regress_loss: 0.2375egr: 0.3882
# 1/1 [==============================] - 1s 795ms/sample - loss: 2.4342 - rpn_out_class_loss: 2.3988 - rpn_out_regress_loss: 0.0353: 0.3891
# 1/1 [==============================] - 1s 987ms/sample - loss: 2.5074 - rpn_out_class_loss: 1.8313 - rpn_out_regress_loss: 0.6760: 0.3912
# 1/1 [==============================] - 1s 734ms/sample - loss: 4.5202 - rpn_out_class_loss: 3.7642 - rpn_out_regress_loss: 0.7561: 0.3917
# 1/1 [==============================] - 1s 957ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 991ms/sample - loss: 3.4946 - rpn_out_class_loss: 3.3207 - rpn_out_regress_loss: 0.1739
# 1/1 [==============================] - 1s 1s/sample - loss: 2.8204 - rpn_out_class_loss: 2.7432 - rpn_out_regress_loss: 0.0771egr: 0.3939
# 1/1 [==============================] - 1s 697ms/sample - loss: 3.6083 - rpn_out_class_loss: 3.4914 - rpn_out_regress_loss: 0.1169: 0.3931
# 1/1 [==============================] - 1s 1s/sample - loss: 2.7311 - rpn_out_class_loss: 2.3749 - rpn_out_regress_loss: 0.3563egr: 0.3942
# 1/1 [==============================] - 1s 813ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 1s/sample - loss: 1.4042 - rpn_out_class_loss: 1.3266 - rpn_out_regress_loss: 0.0776
# 1/1 [==============================] - 1s 870ms/sample - loss: 1.9054 - rpn_out_class_loss: 1.7974 - rpn_out_regress_loss: 0.1080: 0.3945
# 1/1 [==============================] - 1s 1s/sample - loss: 4.0773 - rpn_out_class_loss: 3.6849 - rpn_out_regress_loss: 0.3924egr: 0.3931
# 1/1 [==============================] - 1s 1s/sample - loss: 2.3939 - rpn_out_class_loss: 2.2367 - rpn_out_regress_loss: 0.1572egr: 0.3942
# 1/1 [==============================] - 1s 941ms/sample - loss: 1.8686 - rpn_out_class_loss: 1.6426 - rpn_out_regress_loss: 0.2260: 0.3944
# 1/1 [==============================] - 1s 1s/sample - loss: 2.0948 - rpn_out_class_loss: 1.2733 - rpn_out_regress_loss: 0.8215egr: 0.3951
# 1/1 [==============================] - 1s 1s/sample - loss: 3.2177 - rpn_out_class_loss: 2.9693 - rpn_out_regress_loss: 0.2484egr: 0.3935
# 1/1 [==============================] - 1s 864ms/sample - loss: 3.8882 - rpn_out_class_loss: 3.5421 - rpn_out_regress_loss: 0.3461: 0.3944
# 1/1 [==============================] - 1s 898ms/sample - loss: 3.7391 - rpn_out_class_loss: 3.6447 - rpn_out_regress_loss: 0.0944: 0.3947
# 1/1 [==============================] - 1s 905ms/sample - loss: 3.7232 - rpn_out_class_loss: 2.9194 - rpn_out_regress_loss: 0.8038: 0.3953
# 1/1 [==============================] - 1s 697ms/sample - loss: 3.2590 - rpn_out_class_loss: 2.9295 - rpn_out_regress_loss: 0.3295: 0.3975
# 1/1 [==============================] - 1s 933ms/sample - loss: 2.4561 - rpn_out_class_loss: 2.1736 - rpn_out_regress_loss: 0.2825: 0.3969
# 1/1 [==============================] - 1s 850ms/sample - loss: 4.1281 - rpn_out_class_loss: 3.7282 - rpn_out_regress_loss: 0.3999: 0.3970
# 1/1 [==============================] - 1s 1s/sample - loss: 2.2803 - rpn_out_class_loss: 1.7780 - rpn_out_regress_loss: 0.5023egr: 0.3971
# 1/1 [==============================] - 1s 882ms/sample - loss: 5.2724 - rpn_out_class_loss: 5.2045 - rpn_out_regress_loss: 0.0678: 0.3971
# 1/1 [==============================] - 1s 753ms/sample - loss: 3.4300 - rpn_out_class_loss: 3.1882 - rpn_out_regress_loss: 0.2417: 0.3982
# 1/1 [==============================] - 1s 816ms/sample - loss: 2.9273 - rpn_out_class_loss: 2.7871 - rpn_out_regress_loss: 0.1402: 0.3986
# 1/1 [==============================] - 1s 807ms/sample - loss: 6.4600 - rpn_out_class_loss: 5.5935 - rpn_out_regress_loss: 0.8664: 0.3983
# 1/1 [==============================] - 1s 868ms/sample - loss: 2.6856 - rpn_out_class_loss: 2.5531 - rpn_out_regress_loss: 0.1325: 0.3939
# 1/1 [==============================] - 1s 824ms/sample - loss: 0.6371 - rpn_out_class_loss: 0.0549 - rpn_out_regress_loss: 0.5822: 0.3946
# 1/1 [==============================] - 1s 992ms/sample - loss: 1.3969 - rpn_out_class_loss: 1.3280 - rpn_out_regress_loss: 0.0689: 0.3903
# 1/1 [==============================] - 1s 1s/sample - loss: 3.7590 - rpn_out_class_loss: 2.6123 - rpn_out_regress_loss: 1.1467egr: 0.3898
# 1/1 [==============================] - 1s 921ms/sample - loss: 4.0863 - rpn_out_class_loss: 3.6231 - rpn_out_regress_loss: 0.4632: 0.3906
# 1/1 [==============================] - 1s 915ms/sample - loss: 2.4891 - rpn_out_class_loss: 2.0710 - rpn_out_regress_loss: 0.4181: 0.3910
# 1/1 [==============================] - 1s 887ms/sample - loss: 1.8922 - rpn_out_class_loss: 0.8206 - rpn_out_regress_loss: 1.0716: 0.3913
# 1/1 [==============================] - 1s 944ms/sample - loss: 3.7107 - rpn_out_class_loss: 3.4238 - rpn_out_regress_loss: 0.2869: 0.3905
# 1/1 [==============================] - 1s 917ms/sample - loss: 3.1558 - rpn_out_class_loss: 2.9347 - rpn_out_regress_loss: 0.2211: 0.3905
# 1/1 [==============================] - 1s 869ms/sample - loss: 1.8288 - rpn_out_class_loss: 1.7766 - rpn_out_regress_loss: 0.0522: 0.3910
# 1/1 [==============================] - 1s 891ms/sample - loss: 3.8159 - rpn_out_class_loss: 3.5916 - rpn_out_regress_loss: 0.2244: 0.3901
# 1/1 [==============================] - 1s 877ms/sample - loss: 2.6339 - rpn_out_class_loss: 2.5091 - rpn_out_regress_loss: 0.1248: 0.3867
# 1/1 [==============================] - 1s 1s/sample - loss: 2.2968 - rpn_out_class_loss: 2.2285 - rpn_out_regress_loss: 0.0683egr: 0.3870
# 1/1 [==============================] - 1s 774ms/sample - loss: 4.9795 - rpn_out_class_loss: 4.1852 - rpn_out_regress_loss: 0.7943: 0.3862
# 1/1 [==============================] - 1s 1s/sample - loss: 5.3302 - rpn_out_class_loss: 4.0653 - rpn_out_regress_loss: 1.2649egr: 0.3863
# 1/1 [==============================] - 1s 1s/sample - loss: 1.7419 - rpn_out_class_loss: 1.5861 - rpn_out_regress_loss: 0.1558egr: 0.3872
# 1/1 [==============================] - 1s 832ms/sample - loss: 3.6256 - rpn_out_class_loss: 2.2052 - rpn_out_regress_loss: 1.4204: 0.3881
# 1/1 [==============================] - 1s 929ms/sample - loss: 4.4902 - rpn_out_class_loss: 3.8013 - rpn_out_regress_loss: 0.6889: 0.3882
# 1/1 [==============================] - 1s 1s/sample - loss: 4.6926 - rpn_out_class_loss: 3.9348 - rpn_out_regress_loss: 0.7578egr: 0.3879
# 1/1 [==============================] - 1s 940ms/sample - loss: 4.3199 - rpn_out_class_loss: 3.9437 - rpn_out_regress_loss: 0.3762: 0.3877
# 1/1 [==============================] - 1s 868ms/sample - loss: 2.3734 - rpn_out_class_loss: 2.2477 - rpn_out_regress_loss: 0.1257: 0.3878
# 1/1 [==============================] - 1s 1s/sample - loss: 4.7068 - rpn_out_class_loss: 4.5295 - rpn_out_regress_loss: 0.1773egr: 0.3875
# 1/1 [==============================] - 1s 751ms/sample - loss: 1.9628 - rpn_out_class_loss: 1.8377 - rpn_out_regress_loss: 0.1251: 0.3883
# 1/1 [==============================] - 1s 757ms/sample - loss: 2.4022 - rpn_out_class_loss: 2.3204 - rpn_out_regress_loss: 0.0818: 0.3886
# 1/1 [==============================] - 1s 1s/sample - loss: 2.7876 - rpn_out_class_loss: 2.7616 - rpn_out_regress_loss: 0.0260egr: 0.3883
# 1/1 [==============================] - 1s 886ms/sample - loss: 3.7848 - rpn_out_class_loss: 3.7462 - rpn_out_regress_loss: 0.0387: 0.3876
# 1/1 [==============================] - 1s 829ms/sample - loss: 3.0749 - rpn_out_class_loss: 2.9453 - rpn_out_regress_loss: 0.1296: 0.3869
# 1/1 [==============================] - 1s 1s/sample - loss: 3.4145 - rpn_out_class_loss: 3.2081 - rpn_out_regress_loss: 0.2064egr: 0.3870
# 1/1 [==============================] - 1s 772ms/sample - loss: 4.7790 - rpn_out_class_loss: 4.5004 - rpn_out_regress_loss: 0.2787: 0.3870
# 1/1 [==============================] - 1s 905ms/sample - loss: 2.1220 - rpn_out_class_loss: 1.9293 - rpn_out_regress_loss: 0.1927: 0.3872
# 1/1 [==============================] - 1s 955ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 1s/sample - loss: 2.8407 - rpn_out_class_loss: 1.0746 - rpn_out_regress_loss: 1.7662
# 1/1 [==============================] - 1s 880ms/sample - loss: 4.1918 - rpn_out_class_loss: 3.7755 - rpn_out_regress_loss: 0.4163: 0.3881
# 1/1 [==============================] - 1s 835ms/sample - loss: 7.8936 - rpn_out_class_loss: 7.8321 - rpn_out_regress_loss: 0.0615: 0.3883
# 1/1 [==============================] - 1s 800ms/sample - loss: 4.2581 - rpn_out_class_loss: 3.0579 - rpn_out_regress_loss: 1.2002: 0.3884
# 1/1 [==============================] - 1s 935ms/sample - loss: 2.4149 - rpn_out_class_loss: 2.2630 - rpn_out_regress_loss: 0.1519: 0.3895
# 1/1 [==============================] - 2s 2s/sample - loss: 3.1534 - rpn_out_class_loss: 2.5527 - rpn_out_regress_loss: 0.6007egr: 0.3886
# 1/1 [==============================] - 1s 1s/sample - loss: 3.3625 - rpn_out_class_loss: 2.8796 - rpn_out_regress_loss: 0.4829egr: 0.3897
# 1/1 [==============================] - 1s 893ms/sample - loss: 2.1811 - rpn_out_class_loss: 2.0580 - rpn_out_regress_loss: 0.1231: 0.3900
# 1/1 [==============================] - 1s 909ms/sample - loss: 3.3267 - rpn_out_class_loss: 2.8519 - rpn_out_regress_loss: 0.4747: 0.3898
# 1/1 [==============================] - 1s 655ms/sample - loss: 3.4264 - rpn_out_class_loss: 3.2144 - rpn_out_regress_loss: 0.2120: 0.3897
# 1/1 [==============================] - 1s 1s/sample - loss: 2.9860 - rpn_out_class_loss: 2.6346 - rpn_out_regress_loss: 0.3514egr: 0.3894
# 1/1 [==============================] - 1s 904ms/sample - loss: 3.8169 - rpn_out_class_loss: 3.6911 - rpn_out_regress_loss: 0.1258: 0.3893
# 1/1 [==============================] - 1s 980ms/sample - loss: 4.7311 - rpn_out_class_loss: 4.0336 - rpn_out_regress_loss: 0.6975: 0.3896
# 1/1 [==============================] - 1s 1s/sample - loss: 3.9885 - rpn_out_class_loss: 3.3437 - rpn_out_regress_loss: 0.6448egr: 0.3887
# 1/1 [==============================] - 2s 2s/sample - loss: 3.8923 - rpn_out_class_loss: 2.6330 - rpn_out_regress_loss: 1.2593egr: 0.3894
# 1/1 [==============================] - 1s 888ms/sample - loss: 3.1689 - rpn_out_class_loss: 2.9613 - rpn_out_regress_loss: 0.2076: 0.3881
# 1/1 [==============================] - 1s 817ms/sample - loss: 3.7459 - rpn_out_class_loss: 3.5571 - rpn_out_regress_loss: 0.1888: 0.3876
# 1/1 [==============================] - 1s 994ms/sample - loss: 9.6348 - rpn_out_class_loss: 6.9316 - rpn_out_regress_loss: 2.7032: 0.3871
# 1/1 [==============================] - 1s 963ms/sample - loss: 3.1220 - rpn_out_class_loss: 3.0076 - rpn_out_regress_loss: 0.1144
# 1/1 [==============================] - 1s 1s/sample - loss: 3.2363 - rpn_out_class_loss: 2.9206 - rpn_out_regress_loss: 0.3157egr: 0.3866
# 1/1 [==============================] - 1s 721ms/sample - loss: 2.7166 - rpn_out_class_loss: 2.4661 - rpn_out_regress_loss: 0.2506: 0.3866
# 1/1 [==============================] - 1s 1s/sample - loss: 5.6544 - rpn_out_class_loss: 5.4659 - rpn_out_regress_loss: 0.1885egr: 0.3867
# 1/1 [==============================] - 1s 706ms/sample - loss: 2.5998 - rpn_out_class_loss: 0.6947 - rpn_out_regress_loss: 1.9051: 0.3863
# 1/1 [==============================] - 1s 861ms/sample - loss: 3.4034 - rpn_out_class_loss: 2.7180 - rpn_out_regress_loss: 0.6854
# 1/1 [==============================] - 1s 684ms/sample - loss: 2.0334 - rpn_out_class_loss: 1.8709 - rpn_out_regress_loss: 0.1625: 0.3861
# 1/1 [==============================] - 1s 932ms/sample - loss: 4.3614 - rpn_out_class_loss: 2.8380 - rpn_out_regress_loss: 1.5234: 0.3867
# 1/1 [==============================] - 1s 1s/sample - loss: 1.7525 - rpn_out_class_loss: 1.6877 - rpn_out_regress_loss: 0.0647egr: 0.3867
# 1/1 [==============================] - 1s 918ms/sample - loss: 1.9383 - rpn_out_class_loss: 1.6555 - rpn_out_regress_loss: 0.2829: 0.3863
# 1/1 [==============================] - 1s 915ms/sample - loss: 1.8647 - rpn_out_class_loss: 1.6863 - rpn_out_regress_loss: 0.1784: 0.3863
# 1/1 [==============================] - 2s 2s/sample - loss: 3.4628 - rpn_out_class_loss: 2.5100 - rpn_out_regress_loss: 0.9528egr: 0.3860
# 1/1 [==============================] - 1s 980ms/sample - loss: 0.3540 - rpn_out_class_loss: 0.2113 - rpn_out_regress_loss: 0.1427: 0.3862
# 1/1 [==============================] - 1s 932ms/sample - loss: 4.3905 - rpn_out_class_loss: 4.0649 - rpn_out_regress_loss: 0.3256: 0.3865
# 1/1 [==============================] - 1s 997ms/sample - loss: 6.6131 - rpn_out_class_loss: 6.4066 - rpn_out_regress_loss: 0.2065: 0.3867
# 1/1 [==============================] - 1s 720ms/sample - loss: 3.1480 - rpn_out_class_loss: 2.9369 - rpn_out_regress_loss: 0.2111: 0.3866
# 1/1 [==============================] - 1s 979ms/sample - loss: 3.3234 - rpn_out_class_loss: 3.2454 - rpn_out_regress_loss: 0.0780: 0.3867
# 1/1 [==============================] - 1s 709ms/sample - loss: 2.6693 - rpn_out_class_loss: 2.4772 - rpn_out_regress_loss: 0.1921: 0.3872
# 1/1 [==============================] - 1s 867ms/sample - loss: 3.5551 - rpn_out_class_loss: 3.2303 - rpn_out_regress_loss: 0.3248: 0.3875
# 1/1 [==============================] - 1s 986ms/sample - loss: 2.2713 - rpn_out_class_loss: 2.1774 - rpn_out_regress_loss: 0.0940: 0.3873
# 1/1 [==============================] - 1s 1s/sample - loss: 2.9227 - rpn_out_class_loss: 2.8070 - rpn_out_regress_loss: 0.1157egr: 0.3869
# 1/1 [==============================] - 1s 734ms/sample - loss: 4.0704 - rpn_out_class_loss: 3.6691 - rpn_out_regress_loss: 0.4013: 0.3869
# 1/1 [==============================] - 1s 1s/sample - loss: 3.3294 - rpn_out_class_loss: 2.9541 - rpn_out_regress_loss: 0.3752egr: 0.3872
# 1/1 [==============================] - 1s 808ms/sample - loss: 0.4958 - rpn_out_class_loss: 0.3627 - rpn_out_regress_loss: 0.1331: 0.3872
# 1/1 [==============================] - 1s 884ms/sample - loss: 3.2101 - rpn_out_class_loss: 2.9425 - rpn_out_regress_loss: 0.2675: 0.3874
# 1/1 [==============================] - 1s 1s/sample - loss: 4.8622 - rpn_out_class_loss: 4.4760 - rpn_out_regress_loss: 0.3862egr: 0.3877
# 1/1 [==============================] - 1s 909ms/sample - loss: 2.9283 - rpn_out_class_loss: 2.7540 - rpn_out_regress_loss: 0.1743: 0.3853
# 1/1 [==============================] - 1s 1s/sample - loss: 2.6333 - rpn_out_class_loss: 2.3603 - rpn_out_regress_loss: 0.2731egr: 0.3853
# 1/1 [==============================] - 1s 983ms/sample - loss: 3.2129 - rpn_out_class_loss: 3.0982 - rpn_out_regress_loss: 0.1147: 0.3859
# 1/1 [==============================] - 1s 1s/sample - loss: 2.6439 - rpn_out_class_loss: 2.2727 - rpn_out_regress_loss: 0.3712egr: 0.3858
# 1/1 [==============================] - 1s 718ms/sample - loss: 2.8757 - rpn_out_class_loss: 2.4591 - rpn_out_regress_loss: 0.4166: 0.3860
# 1/1 [==============================] - 1s 1s/sample - loss: 5.9063 - rpn_out_class_loss: 5.5673 - rpn_out_regress_loss: 0.3390egr: 0.3860
# 1/1 [==============================] - 1s 790ms/sample - loss: 0.4422 - rpn_out_class_loss: 0.2920 - rpn_out_regress_loss: 0.1501: 0.3864
# 1/1 [==============================] - 2s 2s/sample - loss: 2.9234 - rpn_out_class_loss: 2.7175 - rpn_out_regress_loss: 0.2058egr: 0.3868
# 1/1 [==============================] - 1s 899ms/sample - loss: 3.8280 - rpn_out_class_loss: 3.4196 - rpn_out_regress_loss: 0.4084: 0.3865
# 1/1 [==============================] - 1s 940ms/sample - loss: 2.3103 - rpn_out_class_loss: 2.1090 - rpn_out_regress_loss: 0.2013: 0.3869
# 1/1 [==============================] - 1s 961ms/sample - loss: 4.2477 - rpn_out_class_loss: 3.5208 - rpn_out_regress_loss: 0.7269: 0.3868
# 1/1 [==============================] - 1s 1s/sample - loss: 3.7847 - rpn_out_class_loss: 3.3480 - rpn_out_regress_loss: 0.4367egr: 0.3866
# 1/1 [==============================] - 1s 750ms/sample - loss: 2.4341 - rpn_out_class_loss: 0.9590 - rpn_out_regress_loss: 1.4751: 0.3868
# 1/1 [==============================] - 1s 938ms/sample - loss: 1.3647 - rpn_out_class_loss: 1.0777 - rpn_out_regress_loss: 0.2870: 0.3857
# 1/1 [==============================] - 1s 1s/sample - loss: 3.8861 - rpn_out_class_loss: 3.6112 - rpn_out_regress_loss: 0.2750egr: 0.3856
# 1/1 [==============================] - 1s 728ms/sample - loss: 0.3139 - rpn_out_class_loss: 0.2104 - rpn_out_regress_loss: 0.1035: 0.3862
# 1/1 [==============================] - 1s 1s/sample - loss: 2.4748 - rpn_out_class_loss: 2.0347 - rpn_out_regress_loss: 0.4401egr: 0.3861
# 1/1 [==============================] - 1s 768ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 1s/sample - loss: 3.9734 - rpn_out_class_loss: 3.6533 - rpn_out_regress_loss: 0.3201
# 1/1 [==============================] - 1s 1s/sample - loss: 4.7302 - rpn_out_class_loss: 4.6691 - rpn_out_regress_loss: 0.0611egr: 0.3865
# 1/1 [==============================] - 1s 1s/sample - loss: 6.5777 - rpn_out_class_loss: 6.4180 - rpn_out_regress_loss: 0.1597egr: 0.3864
# 1/1 [==============================] - 1s 984ms/sample - loss: 4.8104 - rpn_out_class_loss: 4.2061 - rpn_out_regress_loss: 0.6043: 0.3870
# 1/1 [==============================] - 1s 1s/sample - loss: 2.7704 - rpn_out_class_loss: 2.6647 - rpn_out_regress_loss: 0.1057egr: 0.3869
# 1/1 [==============================] - 1s 872ms/sample - loss: 6.3350 - rpn_out_class_loss: 5.1939 - rpn_out_regress_loss: 1.1411: 0.3866
# 1/1 [==============================] - 1s 1s/sample - loss: 1.4938 - rpn_out_class_loss: 1.2786 - rpn_out_regress_loss: 0.2152egr: 0.3864
# 1/1 [==============================] - 1s 1s/sample - loss: 0.4466 - rpn_out_class_loss: 0.3177 - rpn_out_regress_loss: 0.1289egr: 0.3870
# 1/1 [==============================] - 1s 936ms/sample - loss: 5.0576 - rpn_out_class_loss: 4.5268 - rpn_out_regress_loss: 0.5308: 0.3872
# 1/1 [==============================] - 1s 1s/sample - loss: 4.2982 - rpn_out_class_loss: 4.0817 - rpn_out_regress_loss: 0.2165egr: 0.3881
# 1/1 [==============================] - 1s 1s/sample - loss: 4.2974 - rpn_out_class_loss: 3.9839 - rpn_out_regress_loss: 0.3136egr: 0.3887
# 1/1 [==============================] - 1s 820ms/sample - loss: 2.9675 - rpn_out_class_loss: 2.6873 - rpn_out_regress_loss: 0.2802: 0.3893
# 1/1 [==============================] - 1s 630ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 829ms/sample - loss: 3.6891 - rpn_out_class_loss: 2.4026 - rpn_out_regress_loss: 1.2865
# 1/1 [==============================] - 1s 650ms/sample - loss: 2.1963 - rpn_out_class_loss: 1.9559 - rpn_out_regress_loss: 0.2404: 0.3897
# 1/1 [==============================] - 1s 1s/sample - loss: 3.1055 - rpn_out_class_loss: 2.8145 - rpn_out_regress_loss: 0.2910egr: 0.3898
# 1/1 [==============================] - 1s 1s/sample - loss: 2.7199 - rpn_out_class_loss: 2.5791 - rpn_out_regress_loss: 0.1408egr: 0.3894
# 1/1 [==============================] - 1s 1s/sample - loss: 2.2842 - rpn_out_class_loss: 2.1132 - rpn_out_regress_loss: 0.1710egr: 0.3896
# 1/1 [==============================] - 1s 1s/sample - loss: 4.5419 - rpn_out_class_loss: 4.3661 - rpn_out_regress_loss: 0.1758egr: 0.3895
# 1/1 [==============================] - 1s 721ms/sample - loss: 3.1506 - rpn_out_class_loss: 2.8348 - rpn_out_regress_loss: 0.3157: 0.3897
# 1/1 [==============================] - 1s 1s/sample - loss: 2.0679 - rpn_out_class_loss: 2.0027 - rpn_out_regress_loss: 0.0652egr: 0.3900
# 1/1 [==============================] - 1s 702ms/sample - loss: 3.3883 - rpn_out_class_loss: 3.1559 - rpn_out_regress_loss: 0.2324: 0.3898
# 1/1 [==============================] - 1s 897ms/sample - loss: 3.3219 - rpn_out_class_loss: 2.8988 - rpn_out_regress_loss: 0.4232: 0.3896
# 1/1 [==============================] - 1s 812ms/sample - loss: 6.1122 - rpn_out_class_loss: 5.3537 - rpn_out_regress_loss: 0.7585: 0.3892
# 1/1 [==============================] - 1s 1s/sample - loss: 3.1720 - rpn_out_class_loss: 2.9552 - rpn_out_regress_loss: 0.2168egr: 0.3895
# 1/1 [==============================] - 1s 1s/sample - loss: 0.8987 - rpn_out_class_loss: 0.6093 - rpn_out_regress_loss: 0.2893egr: 0.3895
# 1/1 [==============================] - 1s 961ms/sample - loss: 2.4980 - rpn_out_class_loss: 2.3495 - rpn_out_regress_loss: 0.1486: 0.3906
# 1/1 [==============================] - 1s 748ms/sample - loss: 3.7320 - rpn_out_class_loss: 3.3360 - rpn_out_regress_loss: 0.3960: 0.3906
# 1/1 [==============================] - 1s 921ms/sample - loss: 2.0189 - rpn_out_class_loss: 1.7513 - rpn_out_regress_loss: 0.2676: 0.3907
# 1/1 [==============================] - 1s 1s/sample - loss: 2.1607 - rpn_out_class_loss: 2.0098 - rpn_out_regress_loss: 0.1509egr: 0.3906
# 1/1 [==============================] - 1s 771ms/sample - loss: 3.1609 - rpn_out_class_loss: 2.2105 - rpn_out_regress_loss: 0.9503: 0.3911
# 1/1 [==============================] - 1s 901ms/sample - loss: 1.6758 - rpn_out_class_loss: 1.6262 - rpn_out_regress_loss: 0.0497: 0.3911
# 1/1 [==============================] - 1s 778ms/sample - loss: 3.4042 - rpn_out_class_loss: 2.9202 - rpn_out_regress_loss: 0.4840: 0.3907
# 1/1 [==============================] - 1s 1s/sample - loss: 2.9836 - rpn_out_class_loss: 2.8441 - rpn_out_regress_loss: 0.1395egr: 0.3902
# 1/1 [==============================] - 1s 873ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 868ms/sample - loss: 2.9965 - rpn_out_class_loss: 2.8986 - rpn_out_regress_loss: 0.0978
# 1/1 [==============================] - 1s 656ms/sample - loss: 4.1133 - rpn_out_class_loss: 3.9356 - rpn_out_regress_loss: 0.1778: 0.3899
# 1/1 [==============================] - 2s 2s/sample - loss: 4.6166 - rpn_out_class_loss: 3.5254 - rpn_out_regress_loss: 1.0912egr: 0.3898
# 1/1 [==============================] - 1s 917ms/sample - loss: 3.4035 - rpn_out_class_loss: 3.2503 - rpn_out_regress_loss: 0.1532
# 1/1 [==============================] - 1s 841ms/sample - loss: 5.0555 - rpn_out_class_loss: 4.1292 - rpn_out_regress_loss: 0.9263: 0.3894
# 1/1 [==============================] - 1s 924ms/sample - loss: 2.9026 - rpn_out_class_loss: 2.7710 - rpn_out_regress_loss: 0.1316: 0.3900
# 1/1 [==============================] - 1s 1s/sample - loss: 4.3178 - rpn_out_class_loss: 4.2276 - rpn_out_regress_loss: 0.0902egr: 0.3899
# 1/1 [==============================] - 1s 910ms/sample - loss: 2.4076 - rpn_out_class_loss: 2.1649 - rpn_out_regress_loss: 0.2426: 0.3901
# 1/1 [==============================] - 1s 1s/sample - loss: 4.5560 - rpn_out_class_loss: 4.3804 - rpn_out_regress_loss: 0.1755egr: 0.3907
# 1/1 [==============================] - 1s 824ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 893ms/sample - loss: 3.0018 - rpn_out_class_loss: 2.8398 - rpn_out_regress_loss: 0.1620
# 1/1 [==============================] - 1s 838ms/sample - loss: 4.1314 - rpn_out_class_loss: 3.0162 - rpn_out_regress_loss: 1.1151: 0.3899
# 1/1 [==============================] - 1s 834ms/sample - loss: 3.9976 - rpn_out_class_loss: 3.7493 - rpn_out_regress_loss: 0.2483: 0.3899
# 1/1 [==============================] - 1s 708ms/sample - loss: 3.0448 - rpn_out_class_loss: 2.8849 - rpn_out_regress_loss: 0.1599: 0.3903
# 1/1 [==============================] - 1s 695ms/sample - loss: 10.7672 - rpn_out_class_loss: 8.2771 - rpn_out_regress_loss: 2.4901 0.3905
# 1/1 [==============================] - 1s 736ms/sample - loss: 2.1556 - rpn_out_class_loss: 1.9118 - rpn_out_regress_loss: 0.2439
# 1/1 [==============================] - 1s 1s/sample - loss: 2.4461 - rpn_out_class_loss: 2.2205 - rpn_out_regress_loss: 0.2255egr: 0.3911
# 1/1 [==============================] - 1s 856ms/sample - loss: 2.2752 - rpn_out_class_loss: 2.2106 - rpn_out_regress_loss: 0.0646: 0.3908
# 1/1 [==============================] - 1s 754ms/sample - loss: 3.7268 - rpn_out_class_loss: 3.6456 - rpn_out_regress_loss: 0.0812: 0.3906
# 1/1 [==============================] - 1s 1s/sample - loss: 3.6375 - rpn_out_class_loss: 3.2436 - rpn_out_regress_loss: 0.3940egr: 0.3906
# 1/1 [==============================] - 1s 1s/sample - loss: 1.8797 - rpn_out_class_loss: 1.8432 - rpn_out_regress_loss: 0.0365egr: 0.3914
# 1/1 [==============================] - 1s 1s/sample - loss: 3.6897 - rpn_out_class_loss: 3.4125 - rpn_out_regress_loss: 0.2772egr: 0.3912
# 1/1 [==============================] - 1s 863ms/sample - loss: 3.1412 - rpn_out_class_loss: 2.9838 - rpn_out_regress_loss: 0.1575 0.3913
# 1/1 [==============================] - 1s 799ms/sample - loss: 2.3305 - rpn_out_class_loss: 2.1012 - rpn_out_regress_loss: 0.2293 0.3913
# 1/1 [==============================] - 1s 1s/sample - loss: 2.4542 - rpn_out_class_loss: 2.3678 - rpn_out_regress_loss: 0.0864gr: 0.3917
# 1/1 [==============================] - 1s 845ms/sample - loss: 2.3951 - rpn_out_class_loss: 2.3177 - rpn_out_regress_loss: 0.0774 0.3912
# 1/1 [==============================] - 1s 1s/sample - loss: 5.0862 - rpn_out_class_loss: 4.8852 - rpn_out_regress_loss: 0.2010gr: 0.3911
# 1/1 [==============================] - 1s 1s/sample - loss: 2.6912 - rpn_out_class_loss: 2.5825 - rpn_out_regress_loss: 0.1087gr: 0.3909
# 1/1 [==============================] - 1s 887ms/sample - loss: 3.4813 - rpn_out_class_loss: 2.8223 - rpn_out_regress_loss: 0.6590 0.3905
# 1/1 [==============================] - 1s 1s/sample - loss: 2.3263 - rpn_out_class_loss: 1.9128 - rpn_out_regress_loss: 0.4135gr: 0.3910
# 1/1 [==============================] - 1s 1s/sample - loss: 2.8225 - rpn_out_class_loss: 2.5854 - rpn_out_regress_loss: 0.2371gr: 0.3912
# 1/1 [==============================] - 1s 1s/sample - loss: 2.4916 - rpn_out_class_loss: 2.2205 - rpn_out_regress_loss: 0.2711gr: 0.3909
# 1/1 [==============================] - 1s 644ms/sample - loss: 3.4637 - rpn_out_class_loss: 3.3538 - rpn_out_regress_loss: 0.1100 0.3908
# 1/1 [==============================] - 1s 1s/sample - loss: 5.2055 - rpn_out_class_loss: 4.6919 - rpn_out_regress_loss: 0.5136gr: 0.3907
# 1/1 [==============================] - 1s 862ms/sample - loss: 2.7269 - rpn_out_class_loss: 2.6752 - rpn_out_regress_loss: 0.0517 0.3909
# 1/1 [==============================] - 1s 1s/sample - loss: 2.0299 - rpn_out_class_loss: 0.4722 - rpn_out_regress_loss: 1.5577gr: 0.3906
# 1/1 [==============================] - 1s 912ms/sample - loss: 4.6772 - rpn_out_class_loss: 4.4028 - rpn_out_regress_loss: 0.2744
# 1/1 [==============================] - 1s 730ms/sample - loss: 2.4763 - rpn_out_class_loss: 2.2723 - rpn_out_regress_loss: 0.2040 0.3906
# 1/1 [==============================] - 1s 1s/sample - loss: 4.1993 - rpn_out_class_loss: 3.8529 - rpn_out_regress_loss: 0.3464gr: 0.3907
# 1/1 [==============================] - 1s 764ms/sample - loss: 2.0840 - rpn_out_class_loss: 1.9949 - rpn_out_regress_loss: 0.0892 0.3910
# 1/1 [==============================] - 1s 966ms/sample - loss: 2.4894 - rpn_out_class_loss: 2.1811 - rpn_out_regress_loss: 0.3083 0.3911
# 1/1 [==============================] - 1s 617ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 1s/sample - loss: 0.8623 - rpn_out_class_loss: 0.7775 - rpn_out_regress_loss: 0.0848
# 1/1 [==============================] - 1s 1s/sample - loss: 3.3862 - rpn_out_class_loss: 2.9784 - rpn_out_regress_loss: 0.4079gr: 0.3908
# 1/1 [==============================] - 1s 815ms/sample - loss: 6.1187 - rpn_out_class_loss: 5.8199 - rpn_out_regress_loss: 0.2989 0.3905
# 1/1 [==============================] - 1s 900ms/sample - loss: 3.9883 - rpn_out_class_loss: 3.8990 - rpn_out_regress_loss: 0.0893 0.3913
# 1/1 [==============================] - 1s 1s/sample - loss: 2.7811 - rpn_out_class_loss: 2.4223 - rpn_out_regress_loss: 0.3588gr: 0.3911
# 1/1 [==============================] - 2s 2s/sample - loss: 4.5388 - rpn_out_class_loss: 4.4340 - rpn_out_regress_loss: 0.1049gr: 0.3913
# 1/1 [==============================] - 1s 1s/sample - loss: 2.6025 - rpn_out_class_loss: 2.3779 - rpn_out_regress_loss: 0.2246gr: 0.3913
# 1/1 [==============================] - 1s 1s/sample - loss: 4.6379 - rpn_out_class_loss: 4.1430 - rpn_out_regress_loss: 0.4948gr: 0.3910
# 1/1 [==============================] - 1s 1s/sample - loss: 4.3694 - rpn_out_class_loss: 4.1857 - rpn_out_regress_loss: 0.1837gr: 0.3912
# 1/1 [==============================] - 1s 1s/sample - loss: 2.1638 - rpn_out_class_loss: 1.5739 - rpn_out_regress_loss: 0.5899gr: 0.3913
# 1/1 [==============================] - 1s 854ms/sample - loss: 2.5347 - rpn_out_class_loss: 2.3515 - rpn_out_regress_loss: 0.1832 0.3914
# 1/1 [==============================] - 1s 1s/sample - loss: 3.6506 - rpn_out_class_loss: 3.5658 - rpn_out_regress_loss: 0.0848gr: 0.3914
# 1/1 [==============================] - 1s 1s/sample - loss: 3.3914 - rpn_out_class_loss: 3.0129 - rpn_out_regress_loss: 0.3785gr: 0.3911
# 1/1 [==============================] - 1s 769ms/sample - loss: 3.1419 - rpn_out_class_loss: 3.0462 - rpn_out_regress_loss: 0.0956 0.3912
# 1/1 [==============================] - 1s 1s/sample - loss: 3.4305 - rpn_out_class_loss: 2.9769 - rpn_out_regress_loss: 0.4536gr: 0.3911
# 1/1 [==============================] - 1s 1s/sample - loss: 2.2476 - rpn_out_class_loss: 2.1262 - rpn_out_regress_loss: 0.1214gr: 0.3897
# 1/1 [==============================] - 1s 745ms/sample - loss: 2.9235 - rpn_out_class_loss: 2.6623 - rpn_out_regress_loss: 0.2612 0.3899
# 1/1 [==============================] - 1s 969ms/sample - loss: 2.4209 - rpn_out_class_loss: 2.2469 - rpn_out_regress_loss: 0.1740 0.3900
# 1/1 [==============================] - 1s 703ms/sample - loss: 3.3712 - rpn_out_class_loss: 2.9953 - rpn_out_regress_loss: 0.3759 0.3898
# 1/1 [==============================] - 1s 1s/sample - loss: 3.5031 - rpn_out_class_loss: 2.6771 - rpn_out_regress_loss: 0.8260gr: 0.3896
# 1/1 [==============================] - 1s 943ms/sample - loss: 2.4869 - rpn_out_class_loss: 2.4213 - rpn_out_regress_loss: 0.0656 0.3897
# 1/1 [==============================] - 1s 996ms/sample - loss: 4.2013 - rpn_out_class_loss: 4.0075 - rpn_out_regress_loss: 0.1939 0.3896
# 1/1 [==============================] - 1s 1s/sample - loss: 3.7401 - rpn_out_class_loss: 3.4571 - rpn_out_regress_loss: 0.2830gr: 0.3900
# 1/1 [==============================] - 1s 1s/sample - loss: 2.4188 - rpn_out_class_loss: 2.2561 - rpn_out_regress_loss: 0.1627gr: 0.3903
# 1/1 [==============================] - 1s 1s/sample - loss: 3.1388 - rpn_out_class_loss: 3.0076 - rpn_out_regress_loss: 0.1312gr: 0.3901
# 1/1 [==============================] - 1s 731ms/sample - loss: 2.1913 - rpn_out_class_loss: 1.9884 - rpn_out_regress_loss: 0.2028 0.3901
# 1/1 [==============================] - 1s 1s/sample - loss: 7.0334 - rpn_out_class_loss: 6.8974 - rpn_out_regress_loss: 0.1360gr: 0.3902
# 1/1 [==============================] - 1s 916ms/sample - loss: 4.4519 - rpn_out_class_loss: 4.4007 - rpn_out_regress_loss: 0.0512 0.3903
# 1/1 [==============================] - 1s 1s/sample - loss: 0.2949 - rpn_out_class_loss: 0.1048 - rpn_out_regress_loss: 0.1902gr: 0.3901
# 1/1 [==============================] - 1s 692ms/sample - loss: 2.5897 - rpn_out_class_loss: 2.4319 - rpn_out_regress_loss: 0.1578 0.3906
# 1/1 [==============================] - 1s 1s/sample - loss: 3.1195 - rpn_out_class_loss: 2.7439 - rpn_out_regress_loss: 0.3756gr: 0.3902
# 1/1 [==============================] - 1s 1s/sample - loss: 3.2246 - rpn_out_class_loss: 3.1348 - rpn_out_regress_loss: 0.0898gr: 0.3903
# 1/1 [==============================] - 1s 754ms/sample - loss: 3.2511 - rpn_out_class_loss: 2.4027 - rpn_out_regress_loss: 0.8484 0.3901
# 1/1 [==============================] - 1s 1s/sample - loss: 2.7238 - rpn_out_class_loss: 2.5860 - rpn_out_regress_loss: 0.1378gr: 0.3906
# 1/1 [==============================] - 1s 914ms/sample - loss: 3.0988 - rpn_out_class_loss: 3.0573 - rpn_out_regress_loss: 0.0414 0.3904
# 1/1 [==============================] - 1s 1s/sample - loss: 3.0046 - rpn_out_class_loss: 2.9688 - rpn_out_regress_loss: 0.0358gr: 0.3904
# 1/1 [==============================] - 1s 1s/sample - loss: 3.2803 - rpn_out_class_loss: 3.1201 - rpn_out_regress_loss: 0.1602gr: 0.3905
# 1/1 [==============================] - 1s 1s/sample - loss: 6.4672 - rpn_out_class_loss: 6.4106 - rpn_out_regress_loss: 0.0566gr: 0.3902
# 1/1 [==============================] - 1s 699ms/sample - loss: 3.3443 - rpn_out_class_loss: 2.8860 - rpn_out_regress_loss: 0.4583 0.3903
# 1/1 [==============================] - 1s 1s/sample - loss: 3.8450 - rpn_out_class_loss: 3.6949 - rpn_out_regress_loss: 0.1501gr: 0.3905
# 1/1 [==============================] - 1s 789ms/sample - loss: 2.8041 - rpn_out_class_loss: 2.5670 - rpn_out_regress_loss: 0.2371 0.3904
# 1/1 [==============================] - 1s 1s/sample - loss: 2.7868 - rpn_out_class_loss: 2.5655 - rpn_out_regress_loss: 0.2213gr: 0.3911
# 1/1 [==============================] - 1s 835ms/sample - loss: 0.4708 - rpn_out_class_loss: 0.1688 - rpn_out_regress_loss: 0.3020 0.3909
# 1/1 [==============================] - 1s 977ms/sample - loss: 4.2054 - rpn_out_class_loss: 3.7975 - rpn_out_regress_loss: 0.4079 0.3914
# 1/1 [==============================] - 1s 1s/sample - loss: 3.9984 - rpn_out_class_loss: 3.6088 - rpn_out_regress_loss: 0.3896r: 0.3914
# 1/1 [==============================] - 1s 1s/sample - loss: 3.6717 - rpn_out_class_loss: 3.5640 - rpn_out_regress_loss: 0.1077r: 0.3914
# 1/1 [==============================] - 1s 1s/sample - loss: 3.1652 - rpn_out_class_loss: 3.0154 - rpn_out_regress_loss: 0.1497r: 0.3915
# 1/1 [==============================] - 1s 963ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 840ms/sample - loss: 5.5247 - rpn_out_class_loss: 5.3932 - rpn_out_regress_loss: 0.1315
# 1/1 [==============================] - 1s 831ms/sample - loss: 0.3370 - rpn_out_class_loss: 0.1443 - rpn_out_regress_loss: 0.19270.3915
# 1/1 [==============================] - 1s 882ms/sample - loss: 0.0000e+00 - rpn_out_class_loss: 0.0000e+00 - rpn_out_regress_loss: 0.0000e+00
# 1/1 [==============================] - 1s 961ms/sample - loss: 3.6633 - rpn_out_class_loss: 3.3806 - rpn_out_regress_loss: 0.2827
# 299/299 [==============================] - 2620s 9s/step - rpn_cls: 2.8568 - rpn_regr: 0.3138 - detector_cls: 0.9154 - detector_regr: 0.3919
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.77742946708464
# Classifier accuracy for bounding boxes from RPN: 0.5834030100334449
# Loss RPN classifier: 2.856814939316898
# Loss RPN regression: 0.3138123518883883
# Loss Detector classifier: 0.9153999593544964
# Loss Detector regression: 0.39193808433154353
# Elapsed time: 2619.7496581077576
